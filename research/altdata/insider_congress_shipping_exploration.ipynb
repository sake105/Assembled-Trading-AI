# %% [markdown]
# # Experiment: Alternative Daten Exploration (Insider, Congress, Shipping)
#
# ## Hypothese
#
# TODO: Formuliere eine klare Hypothese, z.B.:
# - "Congress-Member-Trades sollten zusätzliches Alpha liefern neben Insider-Trades"
# - "Shipping-Congestion sollte besser für Sektor-Rotation funktionieren als für einzelne Aktien"
#
# ## Setup
#
# TODO: Definiere Experiment-Parameter:
# - Daten-Quellen: Insider, Congress, Shipping
# - Feature-Engineering: Welche Features sollen berechnet werden?
# - Strategie: Wie sollen Features kombiniert werden?
#
# ## Methode
#
# TODO: Implementiere Feature-Engineering und Signal-Generierung
#
# ```python
# # Beispiel:
# from src.assembled_core.data.insider_ingest import load_insider_sample
# from src.assembled_core.features.insider_features import add_insider_features
# from src.assembled_core.signals.rules_event_insider_shipping import generate_event_signals
#
# # Load alternative data
# insider_events = load_insider_sample()
#
# # Add features
# prices_with_features = add_insider_features(prices, insider_events)
#
# # Generate signals
# signals = generate_event_signals(prices_with_features)
# ```
#
# ## Ergebnisse
#
# TODO: Analysiere Feature-Distributionen, Signal-Qualität, Performance
#
# ## Fazit
#
# TODO: War die Hypothese korrekt? Was haben wir gelernt?
#
# ## Nächste Schritte
#
# TODO: Was sollte als nächstes getestet werden?
